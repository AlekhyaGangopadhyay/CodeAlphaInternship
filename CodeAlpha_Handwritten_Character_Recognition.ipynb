# %% [markdown]
# <a href="https://colab.research.google.com/github/AlekhyaGangopadhyay/CodeAlphaInternship/blob/main/CodeAlpha_Handwritten_Character_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow opencv-python

# %% [markdown]
# **MNIST DATASET**

# %%
from tensorflow.keras.datasets import mnist
import numpy as np

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0
X_train = X_train.reshape(-1,28,28,1)
X_test = X_test.reshape(-1,28,28,1)

from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# **USING CNN**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=64,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 48ms/step - accuracy: 0.9402 - loss: 0.1928 - val_accuracy: 0.9844 - val_loss: 0.0458
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 45s 48ms/step - accuracy: 0.9814 - loss: 0.0625 - val_accuracy: 0.9884 - val_loss: 0.0357
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 44s 47ms/step - accuracy: 0.9860 - loss: 0.0456 - val_accuracy: 0.9898 - val_loss: 0.0306
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 44s 47ms/step - accuracy: 0.9898 - loss: 0.0337 - val_accuracy: 0.9911 - val_loss: 0.0264
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 47ms/step - accuracy: 0.9917 - loss: 0.0286 - val_accuracy: 0.9912 - val_loss: 0.0250
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 49ms/step - accuracy: 0.9933 - loss: 0.0222 - val_accuracy: 0.9923 - val_loss: 0.0239
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 44s 47ms/step - accuracy: 0.9934 - loss: 0.0207 - val_accuracy: 0.9921 - val_loss: 0.0245
# Epoch 8/10
# ...

# %%
loss, acc = model.evaluate(X_test, y_test)
print("Accuracy:", acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9932 - loss: 0.0255
# Accuracy: 0.9932000041007996

# %% [markdown]
# **EMNIST DATASET**

# %%
import numpy as np

def load_images(file_path):
    with open(file_path, 'rb') as f:
        data = np.frombuffer(f.read(), dtype=np.uint8, offset=16)
    return data.reshape(-1, 28, 28)

def load_labels(file_path):
    with open(file_path, 'rb') as f:
        data = np.frombuffer(f.read(), dtype=np.uint8, offset=8)
    return data

# %%
X_test = load_images("emnist-balanced-test-images-idx3-ubyte")
y_test = load_labels("emnist-balanced-test-labels-idx1-ubyte")

X_train = load_images("emnist-balanced-train-images-idx3-ubyte")  # YOU NEED THIS
y_train = load_labels("emnist-balanced-train-labels-idx1-ubyte")

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

X_train = X_train.reshape(-1,28,28,1)
X_test = X_test.reshape(-1,28,28,1)

# %%
num_classes = 47

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %% [markdown]
# **USING CNN**

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax')) # Changed to num_classes (47)
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=64,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/10
# 1763/1763 ━━━━━━━━━━━━━━━━━━━━ 91s 51ms/step - accuracy: 0.7229 - loss: 0.8996 - val_accuracy: 0.8406 - val_loss: 0.4729
# Epoch 2/10
# 1763/1763 ━━━━━━━━━━━━━━━━━━━━ 89s 51ms/step - accuracy: 0.8278 - loss: 0.5091 - val_accuracy: 0.8561 - val_loss: 0.4181
# Epoch 3/10
# 1763/1763 ━━━━━━━━━━━━━━━━━━━━ 85s 48ms/step - accuracy: 0.8489 - loss: 0.4360 - val_accuracy: 0.8693 - val_loss: 0.3804
# Epoch 4/10
# 1763/1763 ━━━━━━━━━━━━━━━━━━━━ 86s 49ms/step - accuracy: 0.8602 - loss: 0.3985 - val_accuracy: 0.8702 - val_loss: 0.3673
# Epoch 5/10
# 1763/1763 ━━━━━━━━━━━━━━━━━━━━ 83s 47ms/step - accuracy: 0.8688 - loss: 0.3691 - val_accuracy: 0.8732 - val_loss: 0.3620
# Epoch 6/10
# 1763/1763 ━━━━━━━━━━━━━━━━━━━━ 142s 47ms/step - accuracy: 0.8747 - loss: 0.3464 - val_accuracy: 0.8794 - val_loss: 0.3474
# Epoch 7/10
# 1763/1763 ━━━━━━━━━━━━━━━━━━━━ 84s 48ms/step - accuracy: 0.8789 - loss: 0.3282 - val_accuracy: 0.8811 - val_loss: 0.3507
# Epoch 8/10
# ...

# %%
loss, acc = model.evaluate(X_test, y_test)
print("Accuracy:", acc)
# Out:
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8779 - loss: 0.3608
# Accuracy: 0.8778723478317261
